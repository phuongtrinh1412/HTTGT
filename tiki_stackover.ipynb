# %%
from bs4 import BeautifulSoup
import urllib.request
import csv

url =  'https://stackoverflow.com/'
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, 'html.parser')



objs = soup.find_all('div', class_='question-summary narrow')

with open('data.txt', 'a') as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(['Votes', 'Answer', 'Question Id', 'Question'])
    csvFile.close()
    
for element in objs:
    data = []
    status = element.find_all('div', class_='mini-counts')
    for e in status:
        news = e.find('span')
        title = news.get('title')
        data.append(title)
    
    question_link = element.find('a')
    link = question_link.get('href')
    contentArr = link.split('/')
    data.append(contentArr[2]) 
    data.append(contentArr[3])
    
    with open('data.txt', 'a') as csvFile:
        writer = csv.writer(csvFile)
        writer.writerow(data)
    csvFile.close()

import pandas as pd
name = "data.txt"
data = pd.read_csv(name, lineterminator='\n')
data.head(data.size)
# Out:
#              Votes     Answer Question Id  \
# 1 vote    1 answer   11 views    55568473
# 0 votes  0 answers    3 views    55568428
# 0 votes   1 answer    5 views    55568417
# 0 votes  0 answers    6 views    55568441
# 0 votes  0 answers   56 views    50025183
# 0 votes  0 answers    2 views    55568533
# 0 votes  0 answers    3 views    55568532
# 0 votes  0 answers    2 views    55568529
# 0 votes  0 answers    3 views    55568447
# 0 votes  0 answers    3 views    55568528
# 0 votes  0 answers    3 views    55568527
# 0 votes  0 answers    3 views    55568525
# 0 votes  0 answers    3 views    55568523
# 0 votes  0 answers    4 views    55568521
# 0 votes  0 answers    3 views    55568519
# 0 votes  0 answers    3 views    55568516
# 0 votes  0 answers    3 views    55568514
# 1 vote   3 answers  742 views    53614443
# 0 votes  0 answers    7 views    55568508
# 0 votes  0 answers    5 views    55568503
# 0 votes  0 answers    6 views    55568500
# ...

# %%
from bs4 import BeautifulSoup
import urllib.request
import csv

url =  'https://tiki.vn/nha-cua-doi-song/c1883?src=mega-menu'
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, 'html.parser')


objs = soup.find_all('div', class_ = 'product-item')

with open('tiki.txt', 'a',encoding="utf-8" ) as csvFile:
    writer = csv.writer(csvFile)
    writer.writerow(['Name Product ', 'Price'])
    csvFile.close()
    
for element in objs:
    data = []
    price = element.get('data-price')
    name = element.get('data-title')
    data.append(name)
    data.append(price)
    #print('Name Product: {} - Price: {}'.format(name, price))
    #product_link = element.find('a')
    #print(data)
    with open('tiki.txt', 'a',encoding="utf-8") as csvFile:
        writer = csv.writer(csvFile)
        writer.writerow(data)
    csvFile.close()

import pandas as pd
name = "tiki.txt"
data = pd.read_csv(name, lineterminator='\n')
data.head(data.size)
# Out:
#                                          Name Product     Price\r\r
# 0     Bình Giữ Nhiệt Lưỡng Tính Tiger MCY-A050 (500ml)   329000\r\r
# 1         Tủ Mina Duy Tân 5 Ngăn (Họa Tiết Ngẫu Nhiên)  1140000\r\r
# 2           Hộp Hâm Nóng Arirang Life EL-ALS263 (Tím)    399000\r\r
# 3           Bộ Lau Nhà Homeeasy HT 07 - Màu Ngẫu Nhiên   279000\r\r
# 4    Bộ 10 móc treo dán tường siêu dính chịu lực tố...    17995\r\r
# 5    Kệ để giày dép inox  5 tầng 8800-giao màu ngẫu...   115191\r\r
# 6                         Bộ 4 tượng chú tiểu tứ không    38978\r\r
# 7    Bộ Lau Nhà Lồng Inox Homeeasy Supper Price 666...   199000\r\r
# 8                               Cây lau nhà tự vắt 360    78000\r\r
# 9    Bộ Hộp Cơm Thủy Tinh Lock&Lock 4EA LLG422BTZ3 ...   288000\r\r
# 10   Bộ Túi Hộp Cơm Thủy Tinh Chịu Nhiệt 4EA Lock&L...   259000\r\r
# 11          Combo 10 Móc dán tường chịu lực trong suốt    16910\r\r
# 12   Bộ 3 Hộp Cơm Giữ Nhiệt Lock&Lock Mushroom LHC8...   388000\r\r
# ...
